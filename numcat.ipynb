# %%
import pandas as pd

numcat = pd.read_csv("list_category_img_comma.txt")

# %%
numcat
# Out:
#     Number                       Category
# 0        1    Hooded_Cotton_Canvas_Anorak
# 1        2                         Blazer
# 2        3                         Blouse
# 3        4                         Bomber
# 4        5                    Button-Down
# 5        6                       Cardigan
# 6        7                        Flannel
# 7        8   Paisley_Print_Strappy_Halter
# 8        9                         Henley
# 9       10                         Hoodie
# 10      11                         Jacket
# 11      12                         Jersey
# 12      13                          Parka
# 13      14        Double-Breasted_Peacoat
# 14      15                         Poncho
# 15      16                        Sweater
# 16      17                           Tank
# 17      18                            Tee
# 18      19                            Top
# 19      20                Knit_Turtleneck
# 20      21        Drawstring_Cargo_Capris
# ...

# %%
numcat.set_index(['Number'], inplace=True)

# %%
numcatdf = pd.DataFrame(numcat)

# %%
numcatdf
# Out:
#                              Category
# Number
# 1         Hooded_Cotton_Canvas_Anorak
# 2                              Blazer
# 3                              Blouse
# 4                              Bomber
# 5                         Button-Down
# 6                            Cardigan
# 7                             Flannel
# 8        Paisley_Print_Strappy_Halter
# 9                              Henley
# 10                             Hoodie
# 11                             Jacket
# 12                             Jersey
# 13                              Parka
# 14            Double-Breasted_Peacoat
# 15                             Poncho
# 16                            Sweater
# 17                               Tank
# 18                                Tee
# 19                                Top
# 20                    Knit_Turtleneck
# 21            Drawstring_Cargo_Capris
# 22                             Chinos
# 23                           Culottes
# ...

# %%
numcatdf.to_csv('numcat.csv')
